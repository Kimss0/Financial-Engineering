# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

import tensorflow as tf

# %%
def bscall(S, K, T, r, sig):
    d1 = (np.log(S/K)+(r+0.5*sig**2)*T)/(sig*np.sqrt(T))
    d2 = (np.log(S/K)+(r-0.5*sig**2)*T)/(sig*np.sqrt(T))
    return S*norm.cdf(d1)-K*np.exp(-r*T)*norm.cdf(d2)
    
def bsput(S, K, T, r, sig):
    d1 = (np.log(S/K)+(r+0.5*sig**2)*T)/(sig*np.sqrt(T))
    d2 = (np.log(S/K)+(r-0.5*sig**2)*T)/(sig*np.sqrt(T))
    return K*np.exp(-r*T)*norm.cdf(-d2)-S*norm.cdf(-d1)

# %%
S0 = 1
K1, K2, K3, K4 = 0.85, 0.95, 1.05, 1.15
T = 30/365
r = 0.0
sig = 0.2

M = 1000
N = 30

dt = T/N
rdt = r*dt
sigsdt = sig * np.sqrt(dt)

# %%
np.random.seed(1234)

S = np.empty([M,N+1])
rv = np.random.normal(r*dt,sigsdt,[M,N])

for i in range(M):
    S[i,0] = S0
    for j in range(N):
        S[i,j+1] = S[i,j] * (1+rv[i,j])

# %%
def delta_model(model_name=None):
    price = tf.keras.layers.Input(shape=(1,))
    
    delta = tf.keras.layers.Dense(32, activation='leaky_relu', use_bias=False)(price)
    delta = tf.keras.layers.BatchNormalization()(delta)
    delta = tf.keras.layers.Dense(32, activation='leaky_relu', use_bias=False)(delta)
    delta = tf.keras.layers.BatchNormalization()(delta)
    delta = tf.keras.layers.Dense(32, activation='leaky_relu', use_bias=False)(delta)
    delta = tf.keras.layers.Dense(1, activation='tanh')(delta)

    return tf.keras.Model(inputs=price, outputs=delta, name=model_name)

# %%
price = tf.keras.layers.Input(shape=(1,), name="price")

my_input = [price]

hedge_cost = tf.keras.layers.Lambda(lambda x: x*0.0)(price)

for j in range(N):
    delta = delta_model(model_name="delta_"+str(j))(price)

    new_price = tf.keras.layers.Input(shape=(1,), name='S'+str(j+1))
    my_input += [new_price]

    price_inc = tf.keras.layers.Subtract(name='price_inc_'+str(j))([price, new_price])
    cost = tf.keras.layers.Multiply(name="stock_"+str(j))([delta, price_inc])
    hedge_cost = tf.keras.layers.Add(name='cost_'+str(j))([hedge_cost, cost])

    price = new_price

payoff = tf.keras.layers.Input(shape=(1,), name='payoff')
my_input += [payoff]

cum_cost = tf.keras.layers.Add(name="hedge_cost_plus_payoff")([hedge_cost, payoff])

model = tf.keras.Model(inputs=my_input, outputs=cum_cost)

# %%
SS = [S[:,i].reshape(M,1) for i in range(N+1)]
# payoff = np.maximum(-S[:,-1]+K1, 0) + np.maximum(S[:,-1]-K2, 0) # long strangle
# payoff = np.maximum(S[:,-1]-K1, 0) - 2*np.maximum(S[:,-1]-K2, 0) + np.maximum(S[:,-1]-K3, 0) # long call butterfly
# payoff = np.maximum(K1-S[:,-1], 0) - np.maximum(K2-S[:,-1], 0) # bear put
payoff = np.maximum(S[:,-1]-K1, 0) - np.maximum(S[:,-1]-K2, 0) - np.maximum(K3-S[:,-1], 0) + np.maximum(K4-S[:,-1], 0) # iron condor
x = [SS] + [payoff]
# y = (bsput(S0, K1, T, r, sig) + bscall(S0, K2, T, r, sig)) * np.ones([M,1]) # long strangle
# y = (bscall(S0, K1, T, r, sig) - 2*bscall(S0, K2, T, r, sig) + bscall(S0, K3, T, r, sig)) * np.ones([M,1]) # long call butterfly
# y= (bsput(S0, K2, T, r, sig) - bsput(S0, K1, T, r, sig)) * np.ones([M,1]) # bear put
y = (bscall(S0, K1, T, r, sig) - bscall(S0 ,K2, T, r, sig) - bsput(S0, K3, T, r, sig) + bsput(S0, K4, T, r, sig)) * np.ones([M,1]) # iron condor

# %%
model.compile(loss='mse', optimizer='adam')

# %%
hist = model.fit(x,y, batch_size=32, epochs=200, verbose=True, validation_split=0.2, shuffle=True)
# Out:
# Epoch 1/200
# 25/25 [==============================] - 16s 95ms/step - loss: 5.8535e-04 - val_loss: 3.8030e-04
# Epoch 2/200
# 25/25 [==============================] - 1s 24ms/step - loss: 1.3394e-04 - val_loss: 3.6332e-04
# Epoch 3/200
# 25/25 [==============================] - 1s 24ms/step - loss: 1.2303e-04 - val_loss: 3.5895e-04
# Epoch 4/200
# 25/25 [==============================] - 1s 24ms/step - loss: 7.5582e-05 - val_loss: 3.5664e-04
# Epoch 5/200
# 25/25 [==============================] - 1s 25ms/step - loss: 6.7820e-05 - val_loss: 3.5424e-04
# Epoch 6/200
# 25/25 [==============================] - 1s 25ms/step - loss: 7.0362e-05 - val_loss: 3.5103e-04
# Epoch 7/200
# 25/25 [==============================] - 1s 24ms/step - loss: 7.6260e-05 - val_loss: 3.3973e-04
# Epoch 8/200
# 25/25 [==============================] - 1s 24ms/step - loss: 6.8049e-05 - val_loss: 3.4473e-04
# Epoch 9/200
# 25/25 [==============================] - 1s 25ms/step - loss: 6.6462e-05 - val_loss: 3.4022e-04
# Epoch 10/200
# 25/25 [==============================] - 1s 22ms/step - loss: 6.8070e-05 - val_loss: 3.3589e-04
# Epoch 11/200
# 25/25 [==============================] - 1s 24ms/step - loss: 7.6411e-05 - val_loss: 3.2647e-04
# Epoch 12/200
# 25/25 [==============================] - 1s 23ms/step - loss: 8.2265e-05 - val_loss: 3.1772e-04
# Epoch 13/200
# 25/25 [==============================] - 1s 23ms/step - loss: 7.8057e-05 - val_loss: 3.1577e-04
# Epoch 14/200
# 25/25 [==============================] - 1s 24ms/step - loss: 7.7988e-05 - val_loss: 3.0105e-04
# Epoch 15/200
# 25/25 [==============================] - 1s 23ms/step - loss: 7.1294e-05 - val_loss: 3.0398e-04
# Epoch 16/200
# 25/25 [==============================] - 1s 24ms/step - loss: 6.6219e-05 - val_loss: 2.8453e-04
# Epoch 17/200
# 25/25 [==============================] - 1s 24ms/step - loss: 6.7505e-05 - val_loss: 2.7668e-04
# Epoch 18/200
# 25/25 [==============================] - 1s 24ms/step - loss: 7.3749e-05 - val_loss: 2.7371e-04
# Epoch 19/200
# 25/25 [==============================] - 1s 24ms/step - loss: 6.1912e-05 - val_loss: 2.6747e-04
# Epoch 20/200
# 25/25 [==============================] - 1s 23ms/step - loss: 6.5158e-05 - val_loss: 2.7843e-04
# Epoch 21/200
# 25/25 [==============================] - 1s 23ms/step - loss: 7.9652e-05 - val_loss: 2.6262e-04
# Epoch 22/200
# 25/25 [==============================] - 1s 24ms/step - loss: 6.8470e-05 - val_loss: 2.8053e-04
# Epoch 23/200
# 25/25 [==============================] - 1s 24ms/step - loss: 6.4570e-05 - val_loss: 2.3427e-04
# Epoch 24/200
# 25/25 [==============================] - 1s 23ms/step - loss: 7.4317e-05 - val_loss: 1.8344e-04
# Epoch 25/200
# 25/25 [==============================] - 1s 23ms/step - loss: 6.9055e-05 - val_loss: 2.1486e-04
# Epoch 26/200
# 25/25 [==============================] - 1s 23ms/step - loss: 5.4925e-05 - val_loss: 1.6391e-04
# Epoch 27/200
# 25/25 [==============================] - 1s 21ms/step - loss: 6.1380e-05 - val_loss: 1.6274e-04
# Epoch 28/200
# 25/25 [==============================] - 1s 24ms/step - loss: 6
200
# 25/25 [==============================] - 1s 23ms/step - loss: 5.8784e-05 - val_loss: 2.2336e-04
# Epoch 175/200
# 25/25 [==============================] - 1s 22ms/step - loss: 6.1171e-05 - val_loss: 2.4446e-04
# Epoch 176/200
# 25/25 [==============================] - 1s 23ms/step - loss: 6.2006e-05 - val_loss: 1.6821e-04
# Epoch 177/200
# 25/25 [==============================] - 1s 24ms/step - loss: 5.4437e-05 - val_loss: 2.7123e-04
# Epoch 178/200
# 25/25 [==============================] - 1s 22ms/step - loss: 5.7210e-05 - val_loss: 2.5674e-04
# Epoch 179/200
# 25/25 [==============================] - 1s 24ms/step - loss: 4.6579e-05 - val_loss: 2.2677e-04
# Epoch 180/200
# 25/25 [==============================] - 1s 22ms/step - loss: 4.6553e-05 - val_loss: 1.1368e-04
# Epoch 181/200
# 25/25 [==============================] - 1s 21ms/step - loss: 5.3491e-05 - val_loss: 2.4049e-04
# Epoch 182/200
# 25/25 [==============================] - 1s 21ms/step - loss: 6.0787e-05 - val_loss: 2.2925e-04
# Epoch 183/200
# 25/25 [==============================] - 1s 21ms/step - loss: 5.9706e-05 - val_loss: 2.4562e-04
# Epoch 184/200
# 25/25 [==============================] - 1s 24ms/step - loss: 5.2099e-05 - val_loss: 2.4725e-04
# Epoch 185/200
# 25/25 [==============================] - 1s 22ms/step - loss: 5.3579e-05 - val_loss: 2.3752e-04
# Epoch 186/200
# 25/25 [==============================] - 1s 22ms/step - loss: 5.5891e-05 - val_loss: 2.4110e-04
# Epoch 187/200
# 25/25 [==============================] - 1s 22ms/step - loss: 6.5402e-05 - val_loss: 1.8517e-04
# Epoch 188/200
# 25/25 [==============================] - 1s 22ms/step - loss: 4.9704e-05 - val_loss: 3.1042e-04
# Epoch 189/200
# 25/25 [==============================] - 1s 23ms/step - loss: 5.4860e-05 - val_loss: 2.0737e-04
# Epoch 190/200
# 25/25 [==============================] - 1s 22ms/step - loss: 6.3770e-05 - val_loss: 2.6518e-04
# Epoch 191/200
# 25/25 [==============================] - 1s 24ms/step - loss: 4.7995e-05 - val_loss: 2.1752e-04
# Epoch 192/200
# 25/25 [==============================] - 1s 22ms/step - loss: 5.7748e-05 - val_loss: 1.7766e-04
# Epoch 193/200
# 25/25 [==============================] - 1s 22ms/step - loss: 4.6553e-05 - val_loss: 2.3711e-04
# Epoch 194/200
# 25/25 [==============================] - 1s 21ms/step - loss: 5.4342e-05 - val_loss: 1.9984e-04
# Epoch 195/200
# 25/25 [==============================] - 1s 23ms/step - loss: 5.2087e-05 - val_loss: 1.2464e-04
# Epoch 196/200
# 25/25 [==============================] - 1s 22ms/step - loss: 4.7079e-05 - val_loss: 1.6736e-04
# Epoch 197/200
# 25/25 [==============================] - 1s 22ms/step - loss: 5.5786e-05 - val_loss: 1.5175e-04
# Epoch 198/200
# 25/25 [==============================] - 1s 24ms/step - loss: 4.9420e-05 - val_loss: 1.8051e-04
# Epoch 199/200
# 25/25 [==============================] - 1s 21ms/step - loss: 4.7797e-05 - val_loss: 1.7809e-04
# Epoch 200/200
# 25/25 [==============================] - 1s 24ms/step - loss: 5.3373e-05 - val_loss: 1.5745e-04

# %%
plt.plot(hist.history['loss'])
plt.show()

# %%
yhat = model.predict(x)

# %%
plt.hist(yhat, bins=30); plt.show()

# %%
plt.plot(S[:,-1], yhat, marker='.', linestyle='none'); plt.show()
